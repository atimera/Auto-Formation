# %%
import numpy as np

v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

print("Produit scalaire :", np.dot(v1, v2))

A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

print("Produit matriciel :\n", np.matmul(A, B))
print("Transposée de A :\n", A.T)
